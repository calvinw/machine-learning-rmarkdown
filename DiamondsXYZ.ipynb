# %% [markdown]
# # Diamonds with x,y,z

# %%
options("scipen"=100)
url<-"https://docs.google.com/spreadsheets/d/e/2PACX-1vRg0HUg626uF8xJrZaYZsgOa2Gtfhlnsn00e9fPofb01nRreOucglncXo1xU_cwhueUY8iqC_60ua9t/pub?gid=1994063173&single=true&output=csv"
diamonds<-read.csv(url)
df<-diamonds[100:200,]
row.names(df)<-NULL

# %%
str(df)
# Out:
# 'data.frame':   101 obs. of  10 variables:
#  $ carat  : num  0.72 1.7 0.33 0.73 0.3 0.72 0.7 0.26 0.51 1.01 ...
#  $ cut    : chr  "Very Good" "Premium" "Ideal" "Premium" ...
#  $ color  : chr  "E" "I" "D" "E" ...
#  $ clarity: chr  "VS2" "VS2" "SI2" "VS1" ...
#  $ depth  : num  60 61.2 62 62.6 62.3 62 62.6 63 61.3 61.9 ...
#  $ table  : num  57 59 57 60 57 60 56 58 58 59 ...
#  $ x      : num  5.81 7.55 4.46 5.75 4.27 5.77 5.65 4.08 5.15 6.42 ...
#  $ y      : num  5.86 7.62 4.45 5.68 4.3 5.74 5.69 4.11 5.19 6.37 ...
#  $ z      : num  3.5 4.64 2.76 3.58 2.67 3.57 3.55 2.58 3.17 3.96 ...
#  $ price  : int  3550 11257 631 2826 491 2385 2459 597 1091 3790 ...
#    carat       cut color clarity depth table    x    y    z price
# 1   0.72 Very Good     E     VS2  60.0    57 5.81 5.86 3.50  3550
# 2   1.70   Premium     I     VS2  61.2    59 7.55 7.62 4.64 11257
# 3   0.33     Ideal     D     SI2  62.0    57 4.46 4.45 2.76   631
# 4   0.73   Premium     E     VS1  62.6    60 5.75 5.68 3.58  2826
# 5   0.30     Ideal     H     VS2  62.3    57 4.27 4.30 2.67   491
# 6   0.72   Premium     F     SI1  62.0    60 5.77 5.74 3.57  2385
# 7   0.70 Very Good     E     SI1  62.6    56 5.65 5.69 3.55  2459
# 8   0.26 Very Good     E    VVS2  63.0    58 4.08 4.11 2.58   597
# 9   0.51     Ideal     G     SI2  61.3    58 5.15 5.19 3.17  1091
# 10  1.01   Premium     H     SI2  61.9    59 6.42 6.37 3.96  3790

# %%
df$cut <- NULL
df$depth <- NULL
df$table<-NULL
df$clarity<-NULL
df$color<-NULL
df$carat<-NULL
str(df)
# Out:
# 'data.frame':   101 obs. of  4 variables:
#  $ x    : num  5.81 7.55 4.46 5.75 4.27 5.77 5.65 4.08 5.15 6.42 ...
#  $ y    : num  5.86 7.62 4.45 5.68 4.3 5.74 5.69 4.11 5.19 6.37 ...
#  $ z    : num  3.5 4.64 2.76 3.58 2.67 3.57 3.55 2.58 3.17 3.96 ...
#  $ price: int  3550 11257 631 2826 491 2385 2459 597 1091 3790 ...
#      x    y    z price
# 1 5.81 5.86 3.50  3550
# 2 7.55 7.62 4.64 11257
# 3 4.46 4.45 2.76   631
# 4 5.75 5.68 3.58  2826
# 5 4.27 4.30 2.67   491
# 6 5.77 5.74 3.57  2385

# %%
model<-lm(price~x+y+z,data=df)
summary(model)
# Out:
# Call:
# lm(formula = price ~ x + y + z, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3660.0 -1350.2  -320.5  1187.5  7860.2
#
# Coefficients:
#             Estimate Std. Error t value            Pr(>|t|)
# (Intercept)   -16317       1031 -15.832 <0.0000000000000002 ***
# x              -2425       3873  -0.626               0.533
# y               4375       3870   1.131               0.261
# z               2690       3027   0.889               0.376
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2129 on 97 degrees of freedom
# Multiple R-squared:  0.8084,    Adjusted R-squared:  0.8024
# F-statistic: 136.4 on 3 and 97 DF,  p-value: < 0.00000000000000022

# %%
cor(df)
# Out:
#               x         y         z     price
# x     1.0000000 0.9988780 0.9951029 0.8961200
# y     0.9988780 1.0000000 0.9951071 0.8980268
# z     0.9951029 0.9951071 1.0000000 0.8969778
# price 0.8961200 0.8980268 0.8969778 1.0000000

# %%
plot(df, upper.panel=NULL, pch=19)

# %%
modelXandZ<-lm(price~x+z, data=df)
summary(modelXandZ)
# Out:
# Call:
# lm(formula = price ~ x + z, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3962.7 -1416.8  -108.9  1220.7  7611.4
#
# Coefficients:
#             Estimate Std. Error t value            Pr(>|t|)
# (Intercept)   -16356       1032 -15.855 <0.0000000000000002 ***
# x               1450       1805   0.803               0.424
# z               3510       2943   1.192               0.236
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2132 on 98 degrees of freedom
# Multiple R-squared:  0.8058,    Adjusted R-squared:  0.8019
# F-statistic: 203.4 on 2 and 98 DF,  p-value: < 0.00000000000000022

# %%
modelY<-lm(price~y, data=df)
summary(modelY)
# Out:
# Call:
# lm(formula = price ~ y, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4171.4 -1342.7  -337.8  1237.8  7949.9
#
# Coefficients:
#             Estimate Std. Error t value            Pr(>|t|)
# (Intercept)   -16252       1019  -15.95 <0.0000000000000002 ***
# y               3595        177   20.31 <0.0000000000000002 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2118 on 99 degrees of freedom
# Multiple R-squared:  0.8065,    Adjusted R-squared:  0.8045
# F-statistic: 412.5 on 1 and 99 DF,  p-value: < 0.00000000000000022

# %%
modelX<-lm(price~x, data=df)
summary(modelX)
# Out:
# Call:
# lm(formula = price ~ x, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4373.2 -1521.0  -224.1  1253.5  7783.0
#
# Coefficients:
#             Estimate Std. Error t value            Pr(>|t|)
# (Intercept) -16241.0     1029.2  -15.78 <0.0000000000000002 ***
# x             3591.7      178.8   20.09 <0.0000000000000002 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2136 on 99 degrees of freedom
# Multiple R-squared:  0.803, Adjusted R-squared:  0.801
# F-statistic: 403.6 on 1 and 99 DF,  p-value: < 0.00000000000000022

# %%
modelZ<-lm(price~z, data=df)
summary(modelZ)
# Out:
# Call:
# lm(formula = price ~ z, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4093.1 -1335.3  -179.3  1191.0  7514.1
#
# Coefficients:
#             Estimate Std. Error t value            Pr(>|t|)
# (Intercept) -16353.3     1029.7  -15.88 <0.0000000000000002 ***
# z             5862.7      290.4   20.19 <0.0000000000000002 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2128 on 99 degrees of freedom
# Multiple R-squared:  0.8046,    Adjusted R-squared:  0.8026
# F-statistic: 407.6 on 1 and 99 DF,  p-value: < 0.00000000000000022
